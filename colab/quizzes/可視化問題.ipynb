# %%
#使うライブラリ
# !pip install japanize-matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import japanize_matplotlib
japanize_matplotlib.japanize()
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1問目
# 使うcsvはhist_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問1.png](data:image/png;base64,...)

# %%
df_histab = pd.read_csv('/Users/hironeko1234/Documents/PlayGround/Basic-Phython/Basic-Phython/colab/quizzes/matplotlib_quiz/hist_data.csv')
"""
df_histab = np.loadtxt(
    fname="hist_data.csv", #読み込むファイルのパスと名前
    dtype="float", #floatで読み込む
    delimiter=",", #csvなのでカンマで区切る
)
"""
# print(df_histab)
"""
data1 = np.array(df_histab['SepalLength'])
"""
# グラフを描画する

plt.hist(df_histab['aデータ'], bins = 30, color = "orange", alpha = 0.5, label = "aデータ")
plt.hist(df_histab['bデータ'], bins = 30, color = "cyan", alpha = 0.5, label = "bデータ")
plt.xlabel("温度")
plt.ylabel("度数")
plt.title("aデータとbデータの温度に関する度数分布")
plt.show()

# %% [markdown]
# ## 2問目
# 使うcsvはscatter_data.csvです。下にコードを書いてください。

# %% [markdown]
# ![問2.png](data:image/png;base64,...)

# %%
df_sc012 = pd.read_csv('/Users/hironeko1234/Documents/PlayGround/Basic-Phython/Basic-Phython/colab/quizzes/matplotlib_quiz/scatter_data.csv')


c0 = df_sc012[df_sc012["class"]==0]
c1 = df_sc012[df_sc012["class"]==1]
c2 = df_sc012[df_sc012["class"]==2]

plt.scatter(c0["length (cm)"], c0["width (cm)"], color = "red", label = "class0")
plt.scatter(c1["length (cm)"], c1["width (cm)"], color = "blue", label = "class1")
plt.scatter(c2["length (cm)"], c2["width (cm)"], color = "green", label = "class2")
plt.xlabel("length(cm)")
plt.ylabel("width(cm)")
plt.title("クラス0~2のlengthとwidthに関する散布図")
plt.grid(True)
plt.legend()

# %% [markdown]
# ## 3問目
# 使うcsvはline_data.csvです。下に2つの画像を表示するコードを書いてください。

# %% [markdown]
# ![問3(1).png](data:image/png;base64,...)

# %% [markdown]
# ![問3(2).png](data:image/png;base64,...)

# %%
df_plt3 = pd.read_csv('/Users/hironeko1234/Documents/PlayGround/Basic-Phython/Basic-Phython/colab/quizzes/matplotlib_quiz/line_data.csv')
df_plt3

# 1つ目
xel = df_plt3["期間"]
y1el = df_plt3["件数"]
y2el = df_plt3["費用"]

plt.plot(xel, y1el, marker = "o")
plt.xlabel("期間")
plt.ylabel("件数")
plt.title("期間ごとの件数の推移")
plt.grid(True)

plt.show()
# x軸のラベルが重なるので45°で回転
plt.xticks(rotation=45)

# 2つ目
plt.bar(xel, y2el, width = 0.8)
plt.xlabel("期間")
plt.ylabel("費用(円)")
plt.title("期間ごとの費用の推移")
plt.grid(True)

plt.show()
